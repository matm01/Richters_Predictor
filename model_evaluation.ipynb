# %%
import pandas as pd
from dataloader import dataloader
import pickle

X_train, y_train, X_test = dataloader()

# Read XGB model from pickle file
with open('models/xgb_model.pkl', 'rb') as f:
    xgb_model = pickle.load(f)

# %% [markdown]
# # Variable importances

# %%
pd.DataFrame(zip(X_train.columns, xgb_model.feature_importances_), columns=['feature', 'importance']).sort_values(by='importance', ascending=False)
# Out:
#                                    feature  importance
# 3                           geo_level_3_id    0.087396
# 37            has_secondary_use_use_police    0.083696
# 9                          foundation_type    0.081308
# 0                              building_id    0.056057
# 15            has_superstructure_adobe_mud    0.014930
# 16     has_superstructure_mud_mortar_stone    0.012246
# 2                           geo_level_2_id    0.010650
# 23    has_superstructure_rc_non_engineered    0.010117
# 8                   land_surface_condition    0.009610
# 1                           geo_level_1_id    0.009157
# 14                      plan_configuration    0.009137
# 38                 has_secondary_use_other    0.008599
# 36            has_secondary_use_gov_office    0.008542
# 21               has_superstructure_timber    0.008324
# 11                       ground_floor_type    0.008207
# 4                      count_floors_pre_eq    0.008103
# 32           has_secondary_use_institution    0.007889
# 17           has_superstructure_stone_flag    0.007871
# 19     has_superstructure_mud_mortar_brick    0.007816
# 34              has_secondary_use_industry    0.007766
# 35           has_secondary_use_health_post    0.007742
# 33                has_secondary_use_school    0.007593
# 31                has_secondary_use_rental    0.007570
# 6                          area_percentage    0.007543
# 13                                position    0.007277
# 10                               roof_type    0.007250
# 7                        height_percentage    0.007057
# 22               has_superstructure_bamboo    0.006979
# 20  has_superstructure_cement_mortar_brick    0.006955
# 5                                      age    0.006937
# 12                        other_floor_type    0.006759
# 18  has_superstructure_cement_mortar_stone    0.006684
# 27                          count_families    0.006128
# 24        has_superstructure_rc_engineered    0.005344
# 29           has_secondary_use_agriculture    0.005073
# 25                has_superstructure_other    0.005006
# 26                  legal_ownership_status    0.004850
# 28                       has_secondary_use    0.004310
# 30                 has_secondary_use_hotel    0.003846
