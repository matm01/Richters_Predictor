# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from src.dataloader import dataloader

from src.custom_plots import plot_damage_by_feature

# %% [markdown]
# # Read data

# %%
X_train, y_train, X_test = dataloader()

train = pd.merge(X_train, y_train, on='building_id')

# %% [markdown]
# # Visualizations

# %% [markdown]
# Based on variable importance metrics, we examine the following features graphically in relation to the target variable.
# - `roof_type`
# - `count_floors_pre_eq`
# - `has_secondary_use_other`
# - `has_superstructure_mud_mortar_stone`
# - `has_superstructure_stone_flag`

# %%
plot_damage_by_feature(train, "roof_type")

# %%
plot_damage_by_feature(train, "count_floors_pre_eq")

# %%
plot_damage_by_feature(train, "has_secondary_use_other")

# %%
plot_damage_by_feature(train, "has_superstructure_stone_flag")
